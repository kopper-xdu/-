# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Program1\\vscode\\数模\\A题\\训练数据集\\tick.csv')
day1_num = (data.iloc[:, 0] == 0).sum()
data_1 = data.iloc[:day1_num, 1:]
day2_num = (data.iloc[:, 0] == 1).sum()
data_2 = data.iloc[day1_num:day2_num, 1:]
data_1
# Out:
#        tx_id  best_bid_price_1  best_bid_size_1  best_ask_price_1  \
# 0          0            5325.0             1894            5326.0
# 1          0            5325.0             1864            5326.0
# 2          0            5325.0             1834            5327.0
# 3          1            5325.0             1670            5326.0
# 4          1            5325.0             1518            5326.0
# ...      ...               ...              ...               ...
# 20111   8044            5325.0             3029            5326.0
# 20112   8045            5325.0             3029            5326.0
# 20113   8045            5325.0             3029            5326.0
# 20114   8046            5325.0             3029            5326.0
# 20115   8046            5325.0             2929            5326.0
#
#        best_ask_size_1  best_bid_price_2  best_bid_size_2  best_ask_price_2  \
# 0                  778            5324.0              747            5327.0
# ...

# %%
data_1 = np.array(data_1)
data_2 = np.array(data_2)
data_1.shape
# Out:
# (20116, 23)

# %%
def plot(data, row_num, feature_num):
    plt.figure(figsize=(20, 10))
    plt.scatter(data[:row_num, 0], data[:row_num, feature_num], s=0.1)
    plt.show()

# %%
plot(data_1, 900, 1)
